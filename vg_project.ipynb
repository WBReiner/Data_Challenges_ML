# %%
# import dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('ggplot')
# %matplotlib inline
pd.options.display.max_columns = 25

# %%
# read the data, set the column names, check out the head

#Test results csv
url = 'https://query.data.world/s/s4zuyix6xawjesupvkit66ueqgey5c'
df = pd.read_csv(url, index_col = 0)

display(df)

num_rows = df.count()
print("Number of tests:", str(num_rows))
# Out:
#                                                     Name Platform    Year  \
# Rank
# 1                                             Wii Sports      Wii  2006.0
# 2                                      Super Mario Bros.      NES  1985.0
# 3                                         Mario Kart Wii      Wii  2008.0
# 4                                      Wii Sports Resort      Wii  2009.0
# 5                               Pokemon Red/Pokemon Blue       GB  1996.0
# 6                                                 Tetris       GB  1989.0
# 7                                  New Super Mario Bros.       DS  2006.0
# 8                                               Wii Play      Wii  2006.0
# 9                              New Super Mario Bros. Wii      Wii  2009.0
# 10                                             Duck Hunt      NES  1984.0
# 11                                            Nintendogs       DS  2005.0
# 12                                         Mario Kart DS       DS  2005.0
# ...
